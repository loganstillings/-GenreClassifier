# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

DATASET_PATH = "data.json"

# %%
def load_data(dataset_path):
    with open(dataset_path, "r") as fp:
        data = json.load(fp)
    # convert lists into numpy arrays
    inputs = np.array(data["mfcc"])
    targets = np.array(data["labels"])
    return inputs, targets

# %%
# load data
inputs, targets = load_data(DATASET_PATH)

# split data into train and test sets
inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.3)

# build the network architecture
model = keras.Sequential([
    #input layer
    keras.layers.Flatten(input_shape=(inputs.shape[1], inputs.shape[2])),

    #hidden layers
    keras.layers.Dense(512, activation="relu"), # rele prevents vanishing gradient unlike sigmoid
    keras.layers.Dense(256, activation="relu"),
    keras.layers.Dense(64, activation="relu"),

    #output layer
    keras.layers.Dense(10, activation="softmax"), # 10 nuerons representing the 10 available genres. Softmax normalizes for multiclass
])

# THE MODEL IS OVERFITTING!!!! TODO fix this in new file

# compile the network
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.summary()

# train network
model.fit(inputs_train, targets_train, 
    validation_data=(inputs_test, targets_test),
    epochs=50,
    batch_size=32) # mini batch is a subset of the dataset (16-128 samples). Accurate but also not too slow or memory intensive
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 1690)              0
#
#  dense (Dense)               (None, 512)               865792
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 219/219 [==============================] - 7s 30ms/step - loss: 9.3749 - accuracy: 0.3077 - val_loss: 4.3124 - val_accuracy: 0.3555
# Epoch 2/50
# 219/219 [==============================] - 5s 22ms/step - loss: 3.2272 - accuracy: 0.3967 - val_loss: 2.8999 - val_accuracy: 0.3932
# Epoch 3/50
# 219/219 [==============================] - 5s 21ms/step - loss: 2.2124 - accuracy: 0.4662 - val_loss: 2.5472 - val_accuracy: 0.4362
# Epoch 4/50
# 219/219 [==============================] - 5s 21ms/step - loss: 1.7764 - accuracy: 0.5268 - val_loss: 2.3435 - val_accuracy: 0.4646
# Epoch 5/50
# 219/219 [==============================] - 5s 21ms/step - loss: 1.4531 - accuracy: 0.5827 - val_loss: 2.1893 - val_accuracy: 0.4650
# Epoch 6/50
# 219/219 [==============================] - 5s 21ms/step - loss: 1.2134 - accuracy: 0.6336 - val_loss: 2.4310 - val_accuracy: 0.4533
# Epoch 7/50
# 219/219 [==============================] - 5s 21ms/step - loss: 1.0777 - accuracy: 0.6618 - val_loss: 2.1329 - val_accuracy: 0.4816
# Epoch 8/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.9370 - accuracy: 0.7030 - val_loss: 2.2071 - val_accuracy: 0.4900
# Epoch 9/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.8203 - accuracy: 0.7289 - val_loss: 2.1739 - val_accuracy: 0.4930
# Epoch 10/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.7328 - accuracy: 0.7561 - val_loss: 2.1503 - val_accuracy: 0.5167
# Epoch 11/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.6294 - accuracy: 0.7918 - val_loss: 2.1346 - val_accuracy: 0.5244
# Epoch 12/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.5894 - accuracy: 0.8040 - val_loss: 2.1687 - val_accuracy: 0.5083
# Epoch 13/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4956 - accuracy: 0.8386 - val_loss: 2.0975 - val_accuracy: 0.5150
# Epoch 14/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.4626 - accuracy: 0.8451 - val_loss: 2.1488 - val_accuracy: 0.5454
# Epoch 15/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4173 - accuracy: 0.8597 - val_loss: 2.1129 - val_accuracy: 0.5294
# Epoch 16/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4107 - accuracy: 0.8641 - val_loss: 2.0716 - val_accuracy: 0.5474
# Epoch 17/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3144 - accuracy: 0.8944 - val_loss: 2.0923 - val_accuracy: 0.5591
# Epoch 18/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.2915 - accuracy: 0.9083 - val_loss: 2.0102 - val_accuracy: 0.5537
# Epoch 19/50
# 219/219 [==============================] - 5s 25ms/step - loss: 0.2609 - accuracy: 0.9114 - val_loss: 2.1512 - val_accuracy: 0.5534
# Epoch 20/50
# 219/219 [==============================] - 6s 25ms/step - loss: 0.2330 - accuracy: 0.9279 - val_loss: 2.3594 - val_accuracy: 0.5434
# Epoch 21/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.2939 - accuracy: 0.9070 - val_loss: 2.2135 - val_accuracy: 0.5357
# Epoch 22/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.3385 - accuracy: 0.8923 - val_loss: 2.6808 - val_accuracy: 0.5481
# Epoch 23/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.2492 - accuracy: 0.9185 - val_loss: 2.1686 - val_accuracy: 0.5688
# Epoch 24/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.2033 - accuracy: 0.9316 - val_loss: 2.2297 - val_accuracy: 0.5651
# Epoch 25/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.1513 - accuracy: 0.9518 - val_loss: 2.3378 - val_accuracy: 0.5554
# Epoch 26/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.2153 - accuracy: 0.9335 - val_loss: 2.4826 - val_accuracy: 0.5447
# Epoch 27/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.1972 - accuracy: 0.9376 - val_loss: 2.1703 - val_accuracy: 0.5781
# Epoch 28/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.2032 - accuracy: 0.9310 - val_loss: 2.3453 - val_accuracy: 0.5517
# Epoch 29/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.1759 - accuracy: 0.9419 - val_loss: 2.3507 - val_accuracy: 0.5668
# Epoch 30/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.1536 - accuracy: 0.9525 - val_loss: 2.3564 - val_accuracy: 0.5841
# Epoch 31/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.1839 - accuracy: 0.9415 - val_loss: 2.4679 - val_accuracy: 0.5654
# Epoch 32/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.1512 - accuracy: 0.9505 - val_loss: 2.4260 - val_accuracy: 0.5724
# Epoch 33/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.1947 - accuracy: 0.9379 - val_loss: 2.3415 - val_accuracy: 0.5918
# Epoch 34/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.1000 - accuracy: 0.9664 - val_loss: 2.5550 - val_accuracy: 0.5711
# Epoch 35/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0966 - accuracy: 0.9717 - val_loss: 2.7031 - val_accuracy: 0.5738
# Epoch 36/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.1335 - accuracy: 0.9555 - val_loss: 2.3734 - val_accuracy: 0.5861
# Epoch 37/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.1182 - accuracy: 0.9615 - val_loss: 2.4481 - val_accuracy: 0.5848
# Epoch 38/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0937 - accuracy: 0.9727 - val_loss: 2.4375 - val_accuracy: 0.5901
# Epoch 39/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0497 - accuracy: 0.9858 - val_loss: 2.3606 - val_accuracy: 0.5965
# Epoch 40/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.1641 - accuracy: 0.9481 - val_loss: 2.7073 - val_accuracy: 0.5631
# Epoch 41/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.2837 - accuracy: 0.9092 - val_loss: 2.6209 - val_accuracy: 0.5678
# Epoch 42/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0926 - accuracy: 0.9687 - val_loss: 2.6927 - val_accuracy: 0.5841
# Epoch 43/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0852 - accuracy: 0.9732 - val_loss: 2.3456 - val_accuracy: 0.6005
# Epoch 44/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0362 - accuracy: 0.9904 - val_loss: 2.3599 - val_accuracy: 0.6238
# Epoch 45/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0172 - accuracy: 0.9967 - val_loss: 2.4780 - val_accuracy: 0.6058
# Epoch 46/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0194 - accuracy: 0.9959 - val_loss: 2.3501 - val_accuracy: 0.6095
# Epoch 47/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.1055 - accuracy: 0.9667 - val_loss: 2.8334 - val_accuracy: 0.5844
# Epoch 48/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.5149 - accuracy: 0.8561 - val_loss: 2.5967 - val_accuracy: 0.5808
# Epoch 49/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0952 - accuracy: 0.9694 - val_loss: 2.3963 - val_accuracy: 0.6115
# Epoch 50/50
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0667 - accuracy: 0.9795 - val_loss: 2.6627 - val_accuracy: 0.6075
